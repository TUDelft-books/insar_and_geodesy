# %% [markdown]
# # Notebook 5: Circular Gaussian distribution: signal plus clutter
#
# ## Preparations
#
# - Nothing to download, jolly good!
#
# You dont even have to download this notebook, you can just code in this interactive book. Just wait until you see in the top bar that python is interactive.
#
# (you could still ofcourse download the notebook and $\downarrow$)
#
# Activate environment:
#
# `conda activate workshop-env` (or your own environment)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
# <b>Task 1.1: </b>
#
# 1. From a standard normal (Gaussian) distribution, draw a sample, called `a
# 2. Repeat step 1 and draw a new sample from the same distribution (uncorrelated to the first one) and call it `b`
# 3. Create a complex number $c= a+ib$ where $i= \sqrt{-1}$
# 4. Plot this complex value as a dot in the Argand plane. Scale the axes in the range $[-4, 4]$
#
# You could use `quiver` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.quiver.html
#
# 5. compute the phase of this complex number using standard conventions, call it $\psi$. Print the value of this phase in the upper right corner, in radians and in degrees.
# 6. compute the amplitude of this complex number using standard conventions, call this A. Print the value of this amplitude in the upper right corner, unitless.
# </p>
# </div>

# %%
#YOUR CODE HERE

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
# <b> Task 1.2: Run the above cell a couple of times </b>
#
# - explain  below in a few lines what you did and what you observed
# </p>
# </div>

# %% [markdown]
# <div style="background-color:#FAE99E; color: black; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
# <b>YOUR TEXT CAN GO HERE:</b>
#
#
#
#
#
#
# </div>

# %%
#Our write it as comments
#
#
#
#
#

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
# <b>Task 1.3 </b>
#
# - Repeat the steps from task 1.1, but now draw 1000 samples, and plot all the dots in one single Argand plane. Comment on what you observe
#
# </p>
# </div>

# %%
#YOUR CODE HERE

# %% [markdown]
# <div style="background-color:#FAE99E; color: black; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
# <b>Explain what you observe:</b>
#
#
#
#
#
#
# </div>

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
# <b>Task 2: </b>
#
# 1. Create a histogram of all thousand associated phase values, in radians. Compute the mean, the expectation value and the standarddeviation of these values.
# Printh both in upper right corner of the plot.
# 2. Create a histogram of all thousand associated amplitude values, unitless. Compute the mean, the expectation value, and the standard deviation of these values and print both in the upper right corner of the plot.
#
# Feel free to use the below equations as reference:
#
# $$
# E\{\varphi(\mathbf{x})\} = \mu(\mathbf{x}) = \int_{-\infty}^{\infty} \varphi \, pdf(\varphi) \, dx,
# $$
#
# $$
# \sigma^2_{\varphi(\mathbf{x})} = E\{[\varphi(\mathbf{x}) - \mu(\mathbf{x})]^2\} = \int_{-\infty}^{\infty} (\varphi - \mu(\mathbf{x}))^2 \, pdf(\varphi) \, dx,
# $$
#
# </p>
# </div>

# %%
#YOUR CODE HERE
